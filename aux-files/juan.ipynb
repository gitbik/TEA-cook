# %%
import pandas as pd

# %%
df_region = pd.read_excel("region-cooking.xlsx")
df_region
# Out:
#        Region                                             States  \
# 0       North  Punjab, Haryana, Himachal Pradesh, Jammu & Kas...
# 1        West            Rajasthan, Gujarat, Maharashtra and Goa
# 2       South      Andhra Pradesh, Tamil Nadu, Karnataka, Kerala
# 3     Central  Uttar Pradesh, Bihar, Jharkhand, Madhya Prades...
# 4  North East  Assam, Meghalaya, Tripura, Manipur, Mizoram, N...
# 5        East      West Bengal, Bihar, Jharkhand, Sikkim, Odisha
#
#                                              Cuisine  Unnamed: 3       Meal  \
# 0  Dairy and an assortment of breads. Dal, dry ve...         NaN  Breakfast
# 1  Corn, lentils, and gram flour, as well as nuts...         NaN      Lunch
# 2  In spite of variations across the states, the ...         NaN     Dinner
# 3  Vast majority of the states are vegetarian and...         NaN        NaN
# 4  Staple foods include rice, fish, pork meat, ba...         NaN        NaN
# ...

# %%
state = "Andhra Pradesh"
print(state)

mask = df_region['States'].str.contains(state, case=False, na=False)

df_region[mask].iloc[:,:3]
# Out:
# Andhra Pradesh
#   Region                                         States  \
# 2  South  Andhra Pradesh, Tamil Nadu, Karnataka, Kerala
#
#                                              Cuisine
# 2  In spite of variations across the states, the ...

# %%
df_dail_cook = df_region.iloc[:3,4:] 

df_dail_cook
# Out:
#         Meal          Time                                               Food  \
# 0  Breakfast  7 AM to 8 AM  Eggs, Indian Bread, Cereal, Porridge, Batter Cake
# 1      Lunch  1 PM to 2 PM  Dal, Rice, Roti, Curries, Dry/gravy vegetable ...
# 2     Dinner  8 PM to 9 PM       Dal, Rice, roti, Curries, Veg/Non-veg dishes
#
#                  Beverage
# 0       Tea, Coffee, Milk
# 1        Curd, Buttermilk
# 2  Soup, Curd, Buttermilk

# %%
raw_data = {'name': ['Willard Morris', 'Al Jennings', 'Omar Mullins', 'Spencer McDaniel'],
'age': [20, 19, 22, 21],
'favorite_color': ['blue', 'blue', 'yellow', 'green'],
'grade': [88, 92, 95, 70]}
df = pd.DataFrame(raw_data)
df.head()
# Out:
#                name  age favorite_color  grade
# 0    Willard Morris   20           blue     88
# 1       Al Jennings   19           blue     92
# 2      Omar Mullins   22         yellow     95
# 3  Spencer McDaniel   21          green     70
